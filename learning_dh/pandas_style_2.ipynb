# %%
import pandas as pd
import numpy as np

# %%
random_data = np.random.randint(1, 100, size=(10, 4))
df = pd.DataFrame(random_data, columns=['A', 'B', 'C', 'D'])
nan_indexes = [(0, 1), (2, 3), (4, 0), (5, 2), (7, 3)]

print("Original DataFrame:")
display(df)

df_colors = ['red','blue','green', '#DE970B']
columns_color = dict(zip(df.columns, ['background-color:'+i for i in df_colors]))

def mycolor(table):
    df_to_color = pd.DataFrame(d, index=table.index, columns=table.columns)
    return df_to_color

df.style.apply(mycolor, axis=None)
# Out:
# Original DataFrame:
#     A   B   C   D
# 0  24  54  20  75
# 1  79  97  23  28
# 2  44  76  59  85
# 3  44  63  62  63
# 4  21  22  72  27
# 5  78   8   9  55
# 6   1  45  68   7
# 7  22  92  17  79
# 8  93  61  23  35
# 9  28  92  48  26
# <style type="text/css">
# #T_308b0_row0_col0, #T_308b0_row1_col0, #T_308b0_row2_col0, #T_308b0_row3_col0, #T_308b0_row4_col0, #T_308b0_row5_col0, #T_308b0_row6_col0, #T_308b0_row7_col0, #T_308b0_row8_col0, #T_308b0_row9_col0 {
#   background-color: red;
# }
# #T_308b0_row0_col1, #T_308b0_row1_col1, #T_308b0_row2_col1, #T_308b0_row3_col1, #T_308b0_row4_col1, #T_308b0_row5_col1, #T_308b0_row6_col1, #T_308b0_row7_col1, #T_308b0_row8_col1, #T_308b0_row9_col1 {
#   background-color: blue;
# }
# #T_308b0_row0_col2, #T_308b0_row1_col2, #T_308b0_row2_col2, #T_308b0_row3_col2, #T_308b0_row4_col2, #T_308b0_row5_col2, #T_308b0_row6_col2, #T_308b0_row7_col2, #T_308b0_row8_col2, #T_308b0_row9_col2 {
#   background-color: green;
# }
# ...
